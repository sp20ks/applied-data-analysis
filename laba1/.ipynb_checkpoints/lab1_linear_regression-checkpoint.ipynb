# %% [markdown]
# # Лабораторная работа 1. Тема: Прогнозирование моделью линейной регрессии

# %% [markdown]
# ## 1. Загрузка данных

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

df = pd.read_csv('./source_data/var17.csv')
y = df['Y'].replace(',', '.', regex=True).astype(float) # заменяем , на . и приводим к типу float
x = df.loc[:, 'х1':'x9'].replace(',', '.', regex=True).astype(float)

# выведем первые несколько строк каждой из матриц
print("Целевая переменная Y:")
print(y.head())

print("\nПризнаки x1 до x9:")
print(x.head())
# Out:
# Целевая переменная Y:
# 0    60.1
# 1    58.5
# 2    57.4
# 3    58.5
# 4    58.3
# Name: Y, dtype: float64
#
# Признаки x1 до x9:
#     х1    х2   х3   х4    х5     х6     x7    x8      x9
# 0  9.2  15.9  7.8  5.3  16.7  169.0  148.0  22.7  2094.0
# 1  7.6  16.4  6.7  4.7  15.5  144.0  150.0  27.9  1768.0
# 2  7.3  18.3  6.3  4.9  19.6  138.0  133.0  33.7  1982.0
# 3  7.9  16.4  6.8  5.0  17.6  197.0  155.0  26.6  1621.0
# 4  7.9  17.0  6.3  4.4  20.1  182.0  159.0  30.5  1631.0

# %% [markdown]
# ## 2. Нормирование данных

# %% [markdown]
# Для нормирования будет использоваться метод Z-нормализации. Был выбран именно этот метод нормирования, так как разброс данных велик.

# %%
x_norm = (x - x.mean())/x.std()
print(f"Нормализованные признаки x1 до x9:\n{x_norm.head()}")
# Out:
# Нормализованные признаки x1 до x9:
#          х1        х2        х3        х4        х5        х6        x7
# 0 -0.312419  0.641913  1.047936  0.587427 -0.639398  0.030370 -0.324137  \
# 1 -0.869042  0.828558 -0.777816  0.083918 -0.943448 -0.356848 -0.279032
# 2 -0.973409  1.537809 -1.441726  0.251754  0.095388 -0.449780 -0.662425
# 3 -0.764675  0.828558 -0.611838  0.335673 -0.411361  0.464054 -0.166270
# 4 -0.764675  1.052532 -1.441726 -0.167836  0.222075  0.231723 -0.076059
#
#          x8        x9
# 0 -0.814685  0.153938
# 1 -0.370312 -0.324449
# 2  0.125336 -0.010416
# 3 -0.481405 -0.540163
# 4 -0.148125 -0.525488

# %% [markdown]
# ## 3. Расчет весов линейной регрессии по аналитической формуле

# %%
# добавляем столбец из единиц для учета свободного члена
x_with_bias = pd.DataFrame(x_norm)
x_with_bias.insert(0, 'bias', 1.0)

# %%
# расчет весов
covar_matrix = np.matmul(np.transpose(x_with_bias), x_with_bias) # ковариационная матрица
inv_matrix = np.linalg.inv(covar_matrix) # обратная ковариационная матрица
tmp = np.matmul(inv_matrix, np.transpose(x_with_bias)) # произведение обратной ковариационной матрицы на транспонированную матрицу нормированных признаков
w = np.matmul(tmp, y) # матрица весов

print(f"Веса линейной регрессии:\n{w.head()}")
# Out:
# Веса линейной регрессии:
# 0    58.131373
# 1    -2.834736
# 2    -2.349336
# 3     0.974707
# 4    -2.267607
# dtype: float64

# %% [markdown]
# ## 4. Построение и интерпретация корреляционной матрицы. Определение степени мультиколлинеарности на основе числа обусловленности

# %%
corr = pd.DataFrame(x_norm).corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_63b2c_row0_col0, #T_63b2c_row1_col1, #T_63b2c_row2_col2, #T_63b2c_row3_col3, #T_63b2c_row4_col4, #T_63b2c_row5_col5, #T_63b2c_row6_col6, #T_63b2c_row7_col7, #T_63b2c_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_63b2c_row0_col1, #T_63b2c_row0_col3, #T_63b2c_row1_col0, #T_63b2c_row2_col8, #T_63b2c_row5_col4, #T_63b2c_row5_col7, #T_63b2c_row7_col5, #T_63b2c_row7_col6, #T_63b2c_row8_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_63b2c_row0_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_63b2c_row0_col4 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_63b2c_row0_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_63b2c_row0_col6, #T_63b2c_row2_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_63b2c_row0_col7 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_63b2c_row0_col8 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_63b2c_row1_col2, #T_63b2c_row6_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_63b2c_row1_col3 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_63b2c_row1_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_63b2c_row1_col5, #T_63b2c_row3_col2, #T_63b2c_row3_col6 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_63b2c_row1_col6 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_63b2c_row1_col7 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_63b2c_row1_col8, #T_63b2c_row3_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_63b2c_row2_col0 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_63b2c_row2_col1 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_63b2c_row2_col3 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_63b2c_row2_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_63b2c_row2_col6, #T_63b2c_row4_col3, #T_63b2c_row4_col7 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_63b2c_row2_col7 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_63b2c_row3_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_63b2c_row3_col1, #T_63b2c_row6_col8 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_63b2c_row3_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_63b2c_row3_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_63b2c_row3_col8 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_63b2c_row4_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_63b2c_row4_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_63b2c_row4_col2, #T_63b2c_row5_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_63b2c_row4_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_63b2c_row4_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_63b2c_row4_col8 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_63b2c_row5_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_63b2c_row5_col1, #T_63b2c_row6_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_63b2c_row5_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_63b2c_row5_col3 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_63b2c_row5_col6 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_63b2c_row6_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_63b2c_row6_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_63b2c_row6_col4 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_63b2c_row6_col5 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_63b2c_row6_col7 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_63b2c_row7_col0 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_63b2c_row7_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_63b2c_row7_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_63b2c_row7_col3 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_63b2c_row7_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_63b2c_row7_col8 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_63b2c_row8_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_63b2c_row8_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_63b2c_row8_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_63b2c_row8_col4 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_63b2c_row8_col5 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_63b2c_row8_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_63b2c_row8_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# </style>
# <table id="T_63b2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63b2c_level0_col0" class="col_heading level0 col0" >х1</th>
#       <th id="T_63b2c_level0_col1" class="col_heading level0 col1" >х2</th>
#       <th id="T_63b2c_level0_col2" class="col_heading level0 col2" >х3</th>
#       <th id="T_63b2c_level0_col3" class="col_heading level0 col3" >х4</th>
#       <th id="T_63b2c_level0_col4" class="col_heading level0 col4" >х5</th>
#       <th id="T_63b2c_level0_col5" class="col_heading level0 col5" >х6</th>
#       <th id="T_63b2c_level0_col6" class="col_heading level0 col6" >x7</th>
#       <th id="T_63b2c_level0_col7" class="col_heading level0 col7" >x8</th>
#       <th id="T_63b2c_level0_col8" class="col_heading level0 col8" >x9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63b2c_level0_row0" class="row_heading level0 row0" >х1</th>
#       <td id="T_63b2c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_63b2c_row0_col1" class="data row0 col1" >-0.657584</td>
#       <td id="T_63b2c_row0_col2" class="data row0 col2" >-0.140233</td>
#       <td id="T_63b2c_row0_col3" class="data row0 col3" >-0.608058</td>
#       <td id="T_63b2c_row0_col4" class="data row0 col4" >0.261887</td>
#       <td id="T_63b2c_row0_col5" class="data row0 col5" >-0.334865</td>
#       <td id="T_63b2c_row0_col6" class="data row0 col6" >-0.343969</td>
#       <td id="T_63b2c_row0_col7" class="data row0 col7" >0.566485</td>
#       <td id="T_63b2c_row0_col8" class="data row0 col8" >-0.190412</td>
#     </tr>
#     <tr>
#       <th id="T_63b2c_level0_row1" class="row_heading level0 row1" >х2</th>
#       <td id="T_63b2c_row1_col0" class="data row1 col0" >-0.657584</td>
#       <td id="T_63b2c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_63b2c_row1_col2" class="data row1 col2" >-0.066188</td>
#       <td id="T_63b2c_row1_col3" class="data row1 col3" >0.042039</td>
#       <td id="T_63b2c_row1_col4" class="data row1 col4" >-0.209115</td>
#       <td id="T_63b2c_row1_col5" class="data row1 col5" >0.245383</td>
#       <td id="T_63b2c_row1_col6" class="data row1 col6" >0.127740</td>
#       <td id="T_63b2c_row1_col7" class="data row1 col7" >-0.328320</td>
#       <td id="T_63b2c_row1_col8" class="data row1 col8" >0.077948</td>
#     </tr>
#     <tr>
#       <th id="T_63b2c_level0_row2" class="row_heading level0 row2" >х3</th>
#       <td id="T_63b2c_row2_col0" class="data row2 col0" >-0.140233</td>
#       <td id="T_63b2c_row2_col1" class="data row2 col1" >-0.066188</td>
#       <td id="T_63b2c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_63b2c_row2_col3" class="data row2 col3" >0.364649</td>
#       <td id="T_63b2c_row2_col4" class="data row2 col4" >-0.082951</td>
#       <td id="T_63b2c_row2_col5" class="data row2 col5" >0.312330</td>
#       <td id="T_63b2c_row2_col6" class="data row2 col6" >0.178473</td>
#       <td id="T_63b2c_row2_col7" class="data row2 col7" >-0.242705</td>
#       <td id="T_63b2c_row2_col8" class="data row2 col8" >-0.316010</td>
#     </tr>
#     <tr>
#       <th id="T_63b2c_level0_row3" class="row_heading level0 row3" >х4</th>
#       <td id="T_63b2c_row3_col0" class="data row3 col0" >-0.608058</td>
#       <td id="T_63b2c_row3_col1" class="data row3 col1" >0.042039</td>
#       <td id="T_63b2c_row3_col2" class="data row3 col2" >0.364649</td>
#       <td id="T_63b2c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_63b2c_row3_col4" class="data row3 col4" >0.137315</td>
#       <td id="T_63b2c_row3_col5" class="data row3 col5" >0.197073</td>
#       <td id="T_63b2c_row3_col6" class="data row3 col6" >0.265641</td

# %% [markdown]
# #### Выводы:
# *Сильная корреляция между Х1 и Х8 может указывать на наличие взаимосвязи между этими признаками.
# *Х6 и Х7 тоже сильно коррелируют, что может указывать на взаимосвязь между ними.
# *Х4 и Х8 имеют умеренную отрицательную корреляцию, что может означать, что при увеличении одного признака, другой уменьшается.
# *Х2, Х5, Х9 практически не коррелируют между собой и с другими признаками.

# %%
# Рассчитываем число обусловленности
condition_number = np.linalg.cond(x_with_bias)

print(f"Число обусловленности: {condition_number}")
# Out:
# Число обусловленности: 6.317368860077602

# %% [markdown]
# Это значение говорит о том, что матрица относительно хорошо обусловлена. Модель линейной регрессии, построенная на этих данных, скорее всего, будет стабильной и устойчивой к небольшим изменениям в данных.

# %% [markdown]
# ## 5. Анализ регрессионных остатков

# %%
# предсказанное значение
y_pred = y_pred = np.matmul(x_with_bias, w.values.reshape(-1, 1))

mse = mean_squared_error(y, y_pred)
rmse = mean_squared_error(y, y_pred)**0.5

determ_coef = r2_score(y, y_pred)

print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"Коэффициент детерминации: {determ_coef}")
# Out:
# MSE: 3.8776385127709503
# RMSE: 1.9691720373728017
# Коэффициент детерминации: 0.5760688390424759

# %% [markdown]
# ## 6. Определение весов линейной регрессии градиентным методом. Проанализировать изменение ошибки от итерации к итерации

# %%
# 1. Инициализация весов
weights = np.ones((x_with_bias.shape[1], 1))
learning_rate = 0.1
S = []
y_reshaped = y.values.reshape(-1, 1)

for _ in range(100):
    # 2. Расчет предсказанного значения y_pred по весам w
    y_pred = np.matmul(x_with_bias, weights)
    dy = y_reshaped - y_pred
    curr = 0
    # 3. Расчет ошибки и градиента функции потерь
    for i in range(y_reshaped.shape[0]):
        curr += pow(y_reshaped[i] - np.transpose(y_pred)[i], 2)
    S.append((1 / x_with_bias.shape[0]) * curr[0])

    # 4. Установка новых значений весов
    dS = (-2 / x_with_bias.shape[0]) * np.matmul(np.transpose(dy), x_with_bias)
    weights -= learning_rate * np.transpose(dS)

for i in range(len(S)):
  print(f"Итерация {i + 1}: {S[i]}")
print(f"MSE: {S[99]}")
print(f"RMSE: {S[99]**0.5}")
R2_grad = r2_score(y, y_pred)
print(f"Коэффициент детерминации: {R2_grad}")
# Out:
# Итерация 1: 3286.4745754403184
# Итерация 2: 2103.9775318030506
# Итерация 3: 1348.6752755123107
# Итерация 4: 865.529796349408
# Итерация 5: 556.3396485694916
# Итерация 6: 358.4264760709314
# Итерация 7: 231.71504647406496
# Итерация 8: 150.56981407015442
# Итерация 9: 98.58885588821242
# Итерация 10: 65.27668813715891
# Итерация 11: 43.91659788159542
# Итерация 12: 30.209706203930374
# Итерация 13: 21.40433032906617
# Итерация 14: 15.738942691973632
# Итерация 15: 12.085737552337145
# Итерация 16: 9.722540979237625
# Итерация 17: 8.18683943407097
# Итерация 18: 7.182355052528094
# Итерация 19: 6.519247378756502
# Итерация 20: 6.075835278090668
# Итерация 21: 5.774092177701316
# Итерация 22: 5.563957081673821
# Итерация 23: 5.41328861626105
# Итерация 24: 5.301431491586986
# Итерация 25: 5.215095675627359
# Итерация 26: 5.14571634775842
# Итерация 27: 5.087762080913705
# Итерация 28: 5.037650320474186
# Итерация 29: 4.993051880238012
# Итерация 30: 4.952444688121484
# Итерация 31: 4.914827275035264
# Итерация 32: 4.879534678096505
# Итерация 33: 4.846120031935585
# Итерация 34: 4.814278314690798
# Итерация 35: 4.783797164462739
# Итерация 36: 4.754525094085714
# Итерация 37: 4.726350899489919
# Итерация 38: 4.699190279008586
# Итерация 39: 4.6729771054541285
# Итерация 40: 4.6476577063109366
# Итерация 41: 4.623187093532012
# Итерация 42: 4.59952646074029
# Итерация 43: 4.576641507420684
# Итерация 44: 4.554501305185824
# Итерация 45: 4.533077521319464
# Итерация 46: 4.512343879360676
# Итерация 47: 4.492275778196078
# Итерация 48: 4.4728500181265645
# Итерация 49: 4.454044599902439
# Итерация 50: 4.435838574137178
# Итерация 51: 4.4182119259754975
# Итерация 52: 4.401145484798269
# Итерация 53: 4.384620851989249
# Итерация 54: 4.368620341947471
# Итерация 55: 4.353126932976891
# Итерация 56: 4.338124225665747
# Итерация 57: 4.323596407038681
# Итерация 58: 4.309528219229297
# Итерация 59: 4.295904931746043
# Итерация 60: 4.282712316635584
# Итерация 61: 4.269936626014148
# Итерация 62: 4.257564571558746
# Итерация 63: 4.245583305640156
# Итерация 64: 4.2339804038467745
# Итерация 65: 4.2227438486996185
# Итерация 66: 4.211862014397937
# Итерация 67: 4.201323652465437
# Итерация 68: 4.191117878190682
# Итерация 69: 4.1812341577742185
# Итерация 70: 4.1716622961097025
# Итерация 71: 4.162392425138483
# Итерация 72: 4.15341499272637
# Итерация 73: 4.144720752019358
# Итерация 74: 4.136300751241296
# Итерация 75: 4.128146323901515
# Итерация 76: 4.120249079384928
# Итерация 77: 4.112600893900348
# Итерация 78: 4.105193901765828
# Итерация 79: 4.098020487012067
# Итерация 80: 4.091073275287169
# Итерация 81: 4.08434512604751
# Итерация 82: 4.077829125020994
# Итерация 83: 4.0715185769301625
# Итерация 84: 4.065406998463762
# Итерация 85: 4.059488111486045
# Итерация 86: 4.05375583647414
# Итерация 87: 4.048204286174195
# Итерация 88: 4.042827759467897
# Итерация 89: 4.037620735441188
# Итерация 90: 4.0325778676476975
# Итерация 91: 4.027693978559751
# Итерация 92: 4.022964054200113
# Итерация 93: 4.018383238948033
# Итерация 94: 4.013946830513444
# Итерация 95: 4.009650275073629
# Итерация 96: 4.005489162566407
# Итерация 97: 4.001459222134908
# Итерация 98: 3.9975563177184195
# Итерация 99: 3.9937764437846557
# Итерация 100: 3.990115721198623
# MSE: 3.990115721198623
# RMSE: 1.9975274018642706
# Коэффициент детерминации: 0.5637720265900097

# %% [markdown]
# ## 7. Сравнение результатов по аналитическому и градиентному методу

# %% [markdown]
# #### Аналитический метод:

# %% [markdown]
# MSE = 3.8776385127709503
# RMSE = 1.9691720373728017
# Коэффициент детерминации = 0.5760688390424759

# %% [markdown]
# #### Градиентный метод:

# %% [markdown]
# MSE = 3.990115721198623
# RMSE = 1.9975274018642706
# Коэффициент детерминации = 0.5637720265900097

# %% [markdown]
# #### Вывод

# %% [markdown]
# Методы примерно одинаковые, но аналитический дает мЕньшую ошибку.

# %% [markdown]
# ## 8. С помощью библиотеки sklearn сделать fit-predict модели линейнойрегрессии. Сравнить результаты с ранее полученными

# %%
# Создание объекта модели линейной регрессии
model = LinearRegression()

# Обучение модели на тренировочных данных
model.fit(x_norm, y)

# Предсказание значений для тестовых данных
y_pred_sklearn = model.predict(x_norm)

# Вычисление метрик
mse_sklearn = mean_squared_error(y, y_pred_sklearn)
rmse_sklearn = mean_squared_error(y, y_pred_sklearn) ** 0.5
r2_sklearn = r2_score(y, y_pred_sklearn)

print(f"MSE (Scikit-Learn): {mse_sklearn}")
print(f"RMSE (Scikit-Learn): {rmse_sklearn}")
print(f"Коэффициент детерминации (Scikit-Learn): {r2_sklearn}")
# Out:
# MSE (Scikit-Learn): 3.87763851277095
# RMSE (Scikit-Learn): 1.9691720373728014
# Коэффициент детерминации (Scikit-Learn): 0.576068839042476

# %% [markdown]
# Результат совпадает практически полностью с результатами аналитического метода.

# %% [markdown]
# ## 9. С помощью библиотеки statmodels получить «эконометрический» результат обучения модели линейной регрессии

# %%
# Добавление константы к признакам (для вычисления свободного члена)
x_with_bias_sm = sm.add_constant(x_norm)

# Создание модели линейной регрессии с помощью statsmodels
model_sm = sm.OLS(y, x_with_bias_sm)

# Обучение модели
results = model_sm.fit()

# Получение предсказанных значений с использованием обученной модели
y_pred_sm = results.predict(x_with_bias_sm)

# Вычисление MSE
mse_sm = np.mean((y - y_pred_sm) ** 2)

# Вычисление RMSE
rmse_sm = np.sqrt(mse_sm)

print(f"MSE (statsmodels): {mse_sm}")
print(f"RMSE (statsmodels): {rmse_sm}")

# Получение статистического обзора модели
print(results.summary())
# Out:
# MSE (statsmodels): 3.8776385127709467
# RMSE (statsmodels): 1.9691720373728008
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.576
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     6.190
# Date:                Mon, 02 Oct 2023   Prob (F-statistic):           1.81e-05
# Time:                        22:01:23   Log-Likelihood:                -106.92
# No. Observations:                  51   AIC:                             233.8
# Df Residuals:                      41   BIC:                             253.2
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         58.1314      0.308    189.025      0.000      57.510      58.752
# х1            -2.8347      0.753     -3.766      0.001      -4.355      -1.315
# х2            -2.3493      0.559     -4.203      0.000      -3.478      -1.220
# х3             0.9747      0.403      2.420      0.020       0.161       1.788
# х4            -2.2676      0.673     -3.370      0.002      -3.627      -0.909
# х5            -0.3056      0.375     -0.814      0.420      -1.064       0.453
# х6            -0.3088      0.452     -0.684      0.498      -1.221       0.603
# x7            -1.1336      0.463     -2.448      0.019      -2.069      -0.198
# x8            -0.4310      0.500     -0.862      0.394      -1.441       0.579
# x9            -0.6463      0.408     -1.584      0.121      -1.471       0.178
# ==============================================================================
# Omnibus:                       46.829   Durbin-Watson:                   2.432
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              259.303
# Skew:                           2.248   Prob(JB):                     4.93e-57
# Kurtosis:                      13.090   Cond. No.                         6.32
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
